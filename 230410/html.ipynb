# %% [markdown]
# ### beautifulsoup 라이브러리
#
# 1. html tag의 데이터를 쉽게 추출하기 위한 라이브러리
# 2. 웹의 구조를 어느정도 인지를 한 상태에서 라이브러리 사용하면 쉽게 데이터를 추출
# 3. 파서(parser)를 활용하여 파이썬에서 접근이 쉽게 객체 형태로 제공

# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1266 sha256=633a015e13468ef75796ddd088c4ab620ebb200eb665fc0d6e9956576c807801
#   Stored in directory: c:\users\이은진\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
import pprint as pp

# %%
url = "https://www.naver.com"

data = requests.get(url)

# %%
data = data.text

# %%
data.find('네이버')
# Out:
# 356

# %%
data[365:368]
# Out:
# '다양한'

# %%
# html 형태로 파싱
soup = bs(data, 'html.parser')

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
# ...

# %% [markdown]
# - 태그의 이름을 사용해서 검색
#     - soup[태그명] : 해당 태그의 첫 번째 정보를 출력
#     - soup[태그명][속성] : 해당 태그의 첫 번째 속성에 대한 값을 출력

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.string)
# Out:
# <title>NAVER</title>
# title
# NAVER

# %%
print(soup.img)
# Out:
# None

# %% [markdown]
# - find()
#     - HTML 문서 안에서 해당 태그의 첫 번째 정보를 출력
#     - find(속성 = 값): HTML 문서 안에서 해당 속성과 일치하는 값을 가진 태그의 첫 번째 정보 출력

# %%
print(soup.find('a'))
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>

# %%
print(soup.find(id = 'newsstand'))
# Out:
# None

# %% [markdown]
# - find_all()
#     - HTML 문서 안에서 해당 태그에 대한 정보를 모두 출력 (데이터 형태가 list)
#     - list 매개변수 : 리스트의 길이 지정

# %%
print(soup.find_all('span')[2])
# Out:
# <span>관심사 바로가기</span>

# %%
sample = soup.find('div', attrs = {
    'class' : 'media_view'
})

# %%
print(sample)
# Out:
# None

# %%
sample_list = sample.find_all('strong')
print(sample_list)

# %%
sample_list[0].get_text()

# %%
result = []

for i in sample_list:
    result.append(i.get_text())

pp.pprint(result)

# %%
url = "https://finance.naver.com/"

html_data = requests.get(url).text

# %%
soup = bs(html_data, 'html.parser')

# %%
data = soup.find('table', attrs={
    'class' : 'tbl_home'
})

# %%
data2 = data.find('tbody')

# %%
_list = data2.find_all('th')

# %%
result = []

for i in _list:
    result.append(i.get_text())

print(result)
# Out:
# ['KODEX 200선물인버스2X', '누보', '라이콤', '한국ANKOR유전', '에스와이', '지더블유바이텍', 'KODEX 코스닥150선물인버스', 'MDS테크', '피델릭스', '이수페타시스', '삼부토건', '웰바이오텍', '백광산업', '유니온머티리얼', '한탑']

# %%
data3 = data2.find_all('tr', attrs={
    'class' : 'up'
})

# %%
data3
# Out:
# [<tr class="up">
#  <th scope="row"><a href="/item/main.naver?code=332290" onclick="clickcr(this, 'spe.slist', '332290', '2', event);">누보</a></th>
#  <td>3,195</td>
#  <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 220</td>
#  <td> <em class="up"> +7.39% </em> </td>
#  </tr>,
#  <tr class="up">
#  <th scope="row"><a href="/item/main.naver?code=388790" onclick="clickcr(this, 'spe.slist', '388790', '3', event);">라이콤</a></th>
#  <td>4,375</td>
#  <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 670</td>
#  <td> <em class="up"> +18.08% </em> </td>
#  </tr>,
#  <tr class="up">
#  <th scope="row"><a href="/item/main.naver?code=109610" onclick="clickcr(this, 'spe.slist', '109610', '5', event);">에스와이</a></th>
#  <td>4,350</td>
#  <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 425</td>
#  <td> <em class="up"> +10.83% </em> </td>
#  </tr>,
#  <tr class="up">
# ...

# %%
# td 리스트
_list3 = []

for i in data3:
    _sample_list = []
    _sample_list.append(i.find('th').get_text())
    _list4 = i.find_all('td')
    for j in _list4:
        _sample_list.append(j.get_text())
    _list3.append(_sample_list)

_list3
# Out:
# [['누보', '3,195', '상승 220', '  +7.39%  '],
#  ['라이콤', '4,375', '상승 670', '  +18.08%  '],
#  ['에스와이', '4,350', '상승 425', '  +10.83%  '],
#  ['KODEX 코스닥150선물인버스', '4,155', '상승 15', '  +0.36%  '],
#  ['피델릭스', '1,631', '상승 376', '  +29.96%  '],
#  ['이수페타시스', '13,680', '상승 1,150', '  +9.18%  '],
#  ['백광산업', '7,370', '상승 740', '  +11.16%  ']]

# %%
import pandas as pd

# %%
pd.DataFrame(_list3)
# Out:
#                    0       1         2            3
# 0                 누보   3,195    상승 220     +7.39%
# 1                라이콤   4,375    상승 670    +18.08%
# 2               에스와이   4,350    상승 425    +10.83%
# 3  KODEX 코스닥150선물인버스   4,155     상승 15     +0.36%
# 4               피델릭스   1,631    상승 376    +29.96%
# 5             이수페타시스  13,680  상승 1,150     +9.18%
# 6               백광산업   7,370    상승 740    +11.16%
